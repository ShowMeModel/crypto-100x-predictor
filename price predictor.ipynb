# %% [markdown]
# # Predicting 100x crypto coins

# %% [markdown]
# ## Time-series machine-learning model for cryptocurrencies

# %% [markdown]
# **Goal:** to train a predictor which is capable of identyfing "100x" coins and tokens basing solely on the past trace data.
#
# **Definitions:**
#
# * The "100x" term means an asset which price (in USD) grows hundred times fold during short period of data.
# * Let's assume by short period we mean 3 months, 6 months or 12 months.
#
# **Data:** past data on token price is taken from CoinGecko

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd

# %%
from pycoingecko import CoinGeckoAPI

# %%
import random

# %%
from tqdm import tqdm

# %%
import time
import datetime

# %%
import defi.defi_tools as dft

# %% [markdown]
# ## Data

# %% [markdown]
# ### CoinGecko API client

# %%
cg = CoinGeckoAPI()

# %% [markdown]
# #### Test with simple example

# %%
cg.get_price(ids='bitcoin', vs_currencies='usd')
# Out:
# {'bitcoin': {'usd': 27549}}

# %%
cg.get_price(ids='ethereum', 
             vs_currencies='usd,btc', 
             include_market_cap=True, 
             include_24hr_vol=True, 
             include_24hr_change=True, 
             include_last_updated_at=True)
# Out:
# {'ethereum': {'usd': 1868.69,
#   'usd_market_cap': 225013094531.53198,
#   'usd_24h_vol': 7352961352.311256,
#   'usd_24h_change': 1.074688914060943,
#   'btc': 0.0678303,
#   'btc_market_cap': 8167591.1429964965,
#   'btc_24h_vol': 266899.9426054162,
#   'btc_24h_change': -0.07842932474885035,
#   'last_updated_at': 1682246998}}

# %% [markdown]
# ### Parse

# %%
derivatives = cg.get_derivatives()

# %%
f'Number of derivatives downloaded: {len(derivatives)}'
# Out:
# 'Number of derivatives downloaded: 4175'

# %%
random.sample(derivatives, 1)
# Out:
# [{'market': 'BIT (Futures)',
#   'symbol': 'USD-M:RSS3-USD-PERPETUAL',
#   'index_id': 'RSS3',
#   'price': '0.15',
#   'price_percentage_change_24h': 6.9124424,
#   'contract_type': 'perpetual',
#   'index': 0.1508866,
#   'basis': 0.0574271,
#   'spread': 0.4,
#   'funding_rate': 0.01,
#   'open_interest': None,
#   'volume_24h': 1168829.8388,
#   'last_traded_at': 1682246850,
#   'expired_at': None}]

# %% [markdown]
# #### Supported coins

# %%
all_coins_list = cg.get_coins_list()

# %%
random.sample(all_coins_list, 3)
# Out:
# [{'id': 'exodusext', 'symbol': 'ext', 'name': 'ExodusExt'},
#  {'id': 'cryptopunk-7171-hoodie',
#   'symbol': 'hoodie',
#   'name': 'CryptoPunk #7171'},
#  {'id': 'x42-protocol', 'symbol': 'x42', 'name': 'X42 Protocol'}]

# %%
f'Number of all known coin symbols: {len(all_coins_list)}'
# Out:
# 'Number of all known coin symbols: 10723'

# %%
# TODO: check if this holds "tokens" (as categorized by CMC) as well

# %%
cg.get_coin_by_id('shiba-world-cup')

# Looks there is a lot of cool features around a single coin
# Many attributes possibly usefull for some machine learning
# Out:
# {'id': 'shiba-world-cup',
#  'symbol': 'swc',
#  'name': 'Shiba World Cup',
#  'asset_platform_id': 'binance-smart-chain',
#  'platforms': {'binance-smart-chain': '0x27dcc73cbbbe57d006303316dd3e91a0d5d58eea'},
#  'detail_platforms': {'binance-smart-chain': {'decimal_place': 18,
#    'contract_address': '0x27dcc73cbbbe57d006303316dd3e91a0d5d58eea'}},
#  'block_time_in_minutes': 0,
#  'hashing_algorithm': None,
#  'categories': [],
#  'public_notice': None,
#  'additional_notices': ["Kindly be aware of <a href='https://www.coingecko.com/en/glossary/rug-pulled' target='_blank'>liquidity-related risks</a>. This notice is not directed at any project in particular, and is more of a cautionary reminder.",
#   'The following token has a variable tax function on the smart contract to <a href="https://support.coingecko.com/hc/en-us/articles/4499153900185-What-are-variable-taxes-on-Smart-Contracts-">change tax rates post deployment</a>. <br>\nDo your own research and be careful if you are trading this token.\n'],
#  'localization': {'en': 'Shiba World Cup',
#   'de': 'Shiba World Cup',
#   'es': 'Shiba World Cup',
#   'fr': 'Shiba World Cup',
#   'it': 'Shiba World Cup',
#   'pl': 'Shiba World Cup',
#   'ro': 'Shiba World Cup',
#   'hu': 'Shiba World Cup',
#   'nl': 'Shiba World Cup',
#   'pt': 'Shiba World Cup',
#   'sv': 'Shiba World Cup',
#   'vi': 'Shiba World Cup',
#   'tr': 'Shiba World Cup',
#   'ru': 'Shiba World Cup',
#   'ja': 'Shiba World Cup',
#   'zh': 'Shiba World Cup',
#   'zh-tw': 'Shiba World Cup',
#   'ko': 'Shiba World Cup',
#   'ar': 'Shiba World Cup',
#   'th': 'Shiba World Cup',
#   'id': 'Shiba World Cup',
#   'cs': 'Shiba World Cup',
#   'da': 'Shiba World Cup',
#   'el': 'Shiba World Cup',
#   'hi': 'Shiba World Cup',
#   'no': 'Shiba World Cup',
#   'sk': 'Shiba World Cup',
#   'uk': 'Shiba World Cup',
#   'he': 'Shiba World Cup',
#   'fi': 'Shiba World Cup',
#   'bg': 'Shiba World Cup',
#   'hr': 'Shiba World Cup',
#   'lt': 'Shiba World Cup',
#   'sl': 'Shiba World Cup'},
#  'description': {'en': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'de': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'es': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'fr': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'it': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'pl': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'ro': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'hu': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'nl': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'pt': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'sv': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'vi': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'tr': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'ru': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'ja': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'zh': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'zh-tw': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'ko': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'ar': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'th': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'id': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'cs': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'da': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'el': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'hi': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'no': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'sk': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'uk': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'he': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'fi': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'bg': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'hr': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'lt': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.',
#   'sl': 'The Shiba worldcup will start at an initial size pre-public launch. 50% of the amount of the pre sale will be used to grow the fund. Shiba world token taxes will also be used to grow the fund Every week, 70% of the total fund value is contributed to a gambling stack. This stack will be bet throughout the following week. Earnings from the weeksbets will be re-invested into the fund as well as used to buyback and burn Shiba Worldcup tokens, boosting the price and increasing the liquidity.'},
#  'links': {'homepage': ['https://shiba-worldcup.io/', '', ''],
#   'blockchain_site': ['https://bscscan.com/token/0x27dcc73cbbbe57d006303316dd3e91a0d5d58eea',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   'official_forum_url': ['', '', ''],
#   'chat_url': ['', '', ''],
#   'announcement_url': ['', ''],
#   'twitter_screen_name': None,
#   'facebook_username': None,
#   'bitcointalk_thread_identifier': None,
#   'telegram_channel_identifier': 'shibawolrdcup_ENG',
#   'subreddit_url': None,
#   'repos_url': {'github': [], 'bitbucket': []}},
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/28054/thumb/logo.jpg?1667287324',
#   'small': 'https://assets.coingecko.com/coins/images/28054/small/logo.jpg?1667287324',
#   'large': 'https://assets.coingecko.com/coins/images/28054/large/logo.jpg?1667287324'},
#  'country_origin': None,
#  'genesis_date': None,
#  'contract_address': '0x27dcc73cbbbe57d006303316dd3e91a0d5d58eea',
#  'sentiment_votes_up_percentage': None,
#  'sentiment_votes_down_percentage': None,
#  'market_cap_rank': None,
#  'coingecko_rank': None,
#  'coingecko_score': 0.0,
#  'developer_score': 0.0,
#  'community_score': 0.0,
#  'liquidity_score': 0.0,
#  'public_interest_score': 0.0,
#  'market_data': {'current_price': {'aed': 0.00033572,
#    'ars': 0.01948157,
#    'aud': 0.00013631,
#    'bch': 6.84806e-07,
#    'bdt': 0.00968822,
#    'bhd': 3.432e-05,
#    'bmd': 9.142e-05,
#    'bnb': 2.69656e-07,
#    'brl': 0.00044886,
#    'btc': 3.02e-09,
#    'cad': 0.00012359,
#    'chf': 8.163e-05,
#    'clp': 0.072365,
#    'cny': 0.00062819,
#    'czk': 0.00193921,
#    'dkk': 0.00061948,
#    'dot': 1.359e-05,
#    'eos': 7.372e-05,
#    'eth': 4.3707e-08,
#    'eur': 8.234e-05,
#    'gbp': 7.359e-05,
#    'hkd': 0.00071764,
#    'huf': 0.03106217,
#    'idr': 1.35,
#    'ils': 0.00033323,
#    'inr': 0.007482,
#    'jpy': 0.01223334,
#    'krw': 0.119245,
#    'kwd': 2.784e-05,
#    'lkr': 0.02940796,
#    'ltc': 9.40312e-07,
#    'mmk': 0.191188,
#    'mxn': 0.00164654,
#    'myr': 0.00040243,
#    'ngn': 0.04192081,
#    'nok': 0.0009452,
#    'nzd': 0.00014714,
#    'php': 0.00506,
#    'pkr': 0.02557163,
#    'pln': 0.00038592,
#    'rub': 0.00745676,
#    'sar': 0.00034291,
#    'sek': 0.00094448,
#    'sgd': 0.00012162,
#    'thb': 0.00309952,
#    'try': 0.00176983,
#    'twd': 0.00279004,
#    'uah': 0.00336253,
#    'usd': 9.142e-05,
#    'vef': 9.15e-06,
#    'vnd': 2.14,
#    'xag': 3.6e-06,
#    'xau': 4.5609e-08,
#    'xdr': 6.735e-05,
#    'xlm': 0.00085919,
#    'xrp': 0.00017595,
#    'yfi': 1.0036e-08,
#    'zar': 0.00164723,
#    'bits': 0.00302032,
#    'link': 1.145e-05,
#    'sats': 0.302032},
#   'total_value_locked': None,
#   'mcap_to_tvl_ratio': None,
#   'fdv_to_tvl_ratio': None,
#   'roi': None,
#   'ath': {'aed': 0.01046421,
#    'ars': 0.449728,
#    'aud': 0.00451214,
#    'bch': 2.463e-05,
#    'bdt': 0.289997,
#    'bhd': 0.00107417,
#    'bmd': 0.00284897,
#    'bnb': 8.7e-06,
#    'brl': 0.01457616,
#    'btc': 1.46886e-07,
#    'cad': 0.00390714,
#    'chf': 0.00288275,
#    'clp': 2.69,
#    'cny': 0.02078791,
#    'czk': 0.071269,
#    'dkk': 0.02170969,
#    'dot': 0.00043643,
#    'eos': 0.00277959,
#    'eth': 1.98e-06,
#    'eur': 0.00291696,
#    'gbp': 0.00254242,
#    'hkd': 0.02236452,
#    'huf': 1.18,
#    'idr': 44.81,
#    'ils': 0.01019743,
#    'inr': 0.235479,
#    'jpy': 0.421909,
#    'krw': 4.06,
#    'kwd': 0.00088496,
#    'lkr': 1.044,
#    'ltc': 4.582e-05,
#    'mmk': 5.97,
#    'mxn': 0.055941,
#    'myr': 0.01352404,
#    'ngn': 1.25,
#    'nok': 0.03002036,
#    'nzd': 0.00491718,
#    'php': 0.167204,
#    'pkr': 0.630725,
#    'pln': 0.01369884,
#    'rub': 0.177633,
#    'sar': 0.01070895,
#    'sek': 0.03181568,
#    'sgd': 0.00404097,
#    'thb': 0.107679,
#    'try': 0.053062,
#    'twd': 0.09186,
#    'uah': 0.104951,
#    'usd': 0.00284897,
#    'vef': 0.00028527,
#    'vnd': 70.84,
#    'xag': 0.00014559,
#    'xau': 1.74e-06,
#    'xdr': 0.0021219,
#    'xlm': 0.02753889,
#    'xrp': 0.00684359,
#    'yfi': 4.28161e-07,
#    'zar': 0.052285,
#    'bits': 0.146886,
#    'link': 0.00039464,
#    'sats': 14.69},
#   'ath_change_percentage': {'aed': -96.79359,
#    'ars': -95.67067,
#    'aud': -96.98091,
#    'bch': -97.21904,
#    'bdt': -96.66115,
#    'bhd': -96.80666,
#    'bmd': -96.79299,
#    'bnb': -96.90136,
#    'brl': -96.92237,
#    'btc': -97.94487,
#    'cad': -96.83876,
#    'chf': -97.17015,
#    'clp': -97.31271,
#    'cny': -96.97985,
#    'czk': -97.28061,
#    'dkk': -97.1482,
#    'dot': -96.88419,
#    'eos': -97.34803,
#    'eth': -97.79117,
#    'eur': -97.17879,
#    'gbp': -97.10723,
#    'hkd': -96.79303,
#    'huf': -97.37705,
#    'idr': -96.98566,
#    'ils': -96.73416,
#    'inr': -96.8245,
#    'jpy': -97.10217,
#    'krw': -97.06152,
#    'kwd': -96.85561,
#    'lkr': -97.18568,
#    'ltc': -97.94786,
#    'mmk': -96.79814,
#    'mxn': -97.05834,
#    'myr': -97.02607,
#    'ngn': -96.64161,
#    'nok': -96.85332,
#    'nzd': -97.00932,
#    'php': -96.97553,
#    'pkr': -95.94804,
#    'pln': -97.18446,
#    'rub': -95.8046,
#    'sar': -96.79979,
#    'sek': -97.03314,
#    'sgd': -96.99196,
#    'thb': -97.12319,
#    'try': -96.66655,
#    'twd': -96.9645,
#    'uah': -96.79796,
#    'usd': -96.79299,
#    'vef': -96.79299,
#    'vnd': -96.97695,
#    'xag': -97.52868,
#    'xau': -97.38138,
#    'xdr': -96.82773,
#    'xlm': -96.88005,
#    'xrp': -97.42972,
#    'yfi': -97.65495,
#    'zar': -96.85136,
#    'bits': -97.94487,
#    'link': -97.0994,
#    'sats': -97.94487},
#   'ath_date': {'aed': '2022-11-04T03:02:49.015Z',
#    'ars': '2022-11-04T03:02:49.015Z',
#    'aud': '2022-11-04T03:02:49.015Z',
#    'bch': '2022-11-13T10:58:05.838Z',
#    'bdt': '2022-11-04T03:02:49.015Z',
#    'bhd': '2022-11-04T03:02:49.015Z',
#    'bmd': '2022-11-04T03:02:49.015Z',
#    'bnb': '2022-11-13T10:58:05.838Z',
#    'brl': '2022-11-04T03:02:49.015Z',
#    'btc': '2022-11-13T10:58:05.838Z',
#    'cad': '2022-11-04T03:02:49.015Z',
#    'chf': '2022-11-04T03:02:49.015Z',
#    'clp': '2022-11-04T03:02:49.015Z',
#    'cny': '2022-11-04T03:02:49.015Z',
#    'czk': '2022-11-04T03:02:49.015Z',
#    'dkk': '2022-11-04T03:02:49.015Z',
#    'dot': '2022-11-04T03:02:49.015Z',
#    'eos': '2022-11-13T10:58:05.838Z',
#    'eth': '2022-11-13T10:58:05.838Z',
#    'eur': '2022-11-04T03:02:49.015Z',
#    'gbp': '2022-11-04T03:02:49.015Z',
#    'hkd': '2022-11-04T03:02:49.015Z',
#    'huf': '2022-11-04T03:02:49.015Z',
#    'idr': '2022-11-04T03:02:49.015Z',
#    'ils': '2022-11-04T03:02:49.015Z',
#    'inr': '2022-11-04T03:02:49.015Z',
#    'jpy': '2022-11-04T03:02:49.015Z',
#    'krw': '2022-11-04T03:02:49.015Z',
#    'kwd': '2022-11-04T03:02:49.015Z',
#    'lkr': '2022-11-04T03:02:49.015Z',
#    'ltc': '2022-11-04T03:02:49.015Z',
#    'mmk': '2022-11-04T03:02:49.015Z',
#    'mxn': '2022-11-04T03:02:49.015Z',
#    'myr': '2022-11-04T03:02:49.015Z',
#    'ngn': '2022-11-04T03:02:49.015Z',
#    'nok': '2022-11-04T03:02:49.015Z',
#    'nzd': '2022-11-04T03:02:49.015Z',
#    'php': '2022-11-04T03:02:49.015Z',
#    'pkr': '2022-11-04T03:02:49.015Z',
#    'pln': '2022-11-04T03:02:49.015Z',
#    'rub': '2022-11-04T03:02:49.015Z',
#    'sar': '2022-11-04T03:02:49.015Z',
#    'sek': '2022-11-04T03:02:49.015Z',
#    'sgd': '2022-11-04T03:02:49.015Z',
#    'thb': '2022-11-04T03:02:49.015Z',
#    'try': '2022-11-04T03:02:49.015Z',
#    'twd': '2022-11-04T03:02:49.015Z',
#    'uah': '2022-11-04T03:02:49.015Z',
#    'usd': '2022-11-04T03:02:49.015Z',
#    'vef': '2022-11-04T03:02:49.015Z',
#    'vnd': '2022-11-04T03:02:49.015Z',
#    'xag': '2022-11-04T03:02:49.015Z',
#    'xau': '2022-11-04T03:02:49.015Z',
#    'xdr': '2022-11-04T03:02:49.015Z',
#    'xlm': '2022-11-13T10:58:05.838Z',
#    'xrp': '2022-11-13T10:58:05.838Z',
#    'yfi': '2022-11-13T10:58:05.838Z',
#    'zar': '2022-11-04T03:02:49.015Z',
#    'bits': '2022-11-13T10:58:05.838Z',
#    'link': '2022-11-13T10:58:05.838Z',
#    'sats': '2022-11-13T10:58:05.838Z'},
#   'atl': {'aed': 0.00027843,
#    'ars': 0.01513675,
#    'aud': 0.00011507,
#    'bch': 5.93288e-07,
#    'bdt': 0.00799484,
#    'bhd': 2.858e-05,
#    'bmd': 7.581e-05,
#    'bnb': 2.68621e-07,
#    'brl': 0.00039122,
#    'btc': 2.86e-09,
#    'cad': 0.00010486,
#    'chf': 7.047e-05,
#    'clp': 0.060394,
#    'cny': 0.00052794,
#    'czk': 0.00169411,
#    'dkk': 0.00053284,
#    'dot': 1.164e-05,
#    'eos': 6.062e-05,
#    'eth': 4.2072e-08,
#    'eur': 7.16e-05,
#    'gbp': 6.354e-05,
#    'hkd': 0.00059509,
#    'huf': 0.02748039,
#    'idr': 1.17,
#    'ils': 0.0002706,
#    'inr': 0.00622033,
#    'jpy': 0.0103116,
#    'krw': 0.100496,
#    'kwd': 2.33e-05,
#    'lkr': 0.02472518,
#    'ltc': 8.56723e-07,
#    'mmk': 0.159258,
#    'mxn': 0.00138929,
#    'myr': 0.00034273,
#    'ngn': 0.03490969,
#    'nok': 0.00080838,
#    'nzd': 0.0001242,
#    'php': 0.00418647,
#    'pkr': 0.01935931,
#    'pln': 0.00033573,
#    'rub': 0.00575168,
#    'sar': 0.0002846,
#    'sek': 0.00081318,
#    'sgd': 0.00010251,
#    'thb': 0.00265563,
#    'try': 0.00142028,
#    'twd': 0.00233861,
#    'uah': 0.00280085,
#    'usd': 7.581e-05,
#    'vef': 7.59e-06,
#    'vnd': 1.8,
#    'xag': 3.35e-06,
#    'xau': 4.0936e-08,
#    'xdr': 5.702e-05,
#    'xlm': 0.00076433,
#    'xrp': 0.00015585,
#    'yfi': 7.266e-09,
#    'zar': 0.00140076,
#    'bits': 0.00285951,
#    'link': 1.084e-05,
#    'sats': 0.285951},
#   'atl_change_percentage': {'aed': 20.50684,
#    'ars': 28.62881,
#    'aud': 18.38225,
#    'bch': 15.46218,
#    'bdt': 21.11026,
#    'bhd': 20.02866,
#    'bmd': 20.52324,
#    'bnb': 0.41192,
#    'brl': 14.66827,
#    'btc': 5.56686,
#    'cad': 17.78386,
#    'chf': 15.7683,
#    'clp': 19.75114,
#    'cny': 18.92062,
#    'czk': 14.40087,
#    'dkk': 16.19113,
#    'dot': 16.85112,
#    'eos': 21.59767,
#    'eth': 3.82733,
#    'eur': 14.93833,
#    'gbp': 15.74425,
#    'hkd': 20.52374,
#    'huf': 12.96805,
#    'idr': 15.06242,
#    'ils': 23.07141,
#    'inr': 20.21281,
#    'jpy': 18.56754,
#    'krw': 18.58712,
#    'kwd': 19.41792,
#    'lkr': 18.87002,
#    'ltc': 9.76305,
#    'mmk': 19.97893,
#    'mxn': 18.44797,
#    'myr': 17.35088,
#    'ngn': 20.01361,
#    'nok': 16.85644,
#    'nzd': 18.40262,
#    'php': 20.79494,
#    'pkr': 32.01259,
#    'pln': 14.88411,
#    'rub': 29.56933,
#    'sar': 20.4156,
#    'sek': 16.0777,
#    'sgd': 18.57808,
#    'thb': 16.64717,
#    'try': 24.53874,
#    'twd': 19.23396,
#    'uah': 19.98405,
#    'usd': 20.52324,
#    'vef': 20.52324,
#    'vnd': 19.20105,
#    'xag': 7.34284,
#    'xau': 11.35018,
#    'xdr': 18.05048,
#    'xlm': 12.41224,
#    'xrp': 12.86293,
#    'yfi': 38.1813,
#    'zar': 17.52643,
#    'bits': 5.56686,
#    'link': 5.61588,
#    'sats': 5.56686},
#   'atl_date': {'aed': '2023-03-09T21:02:30.419Z',
#    'ars': '2023-01-01T05:05:06.583Z',
#    'aud': '2023-03-09T21:02:30.419Z',
#    'bch': '2023-02-21T01:51:10.118Z',
#    'bdt': '2023-03-09T21:02:30.419Z',
#    'bhd': '2023-03-09T21:02:30.419Z',
#    'bmd': '2023-03-09T21:02:30.419Z',
#    'bnb': '2023-04-11T16:51:28.317Z',
#    'brl': '2023-03-09T21:02:30.419Z',
#    'btc': '2023-04-13T06:02:21.061Z',
#    'cad': '2023-03-09T21:02:30.419Z',
#    'chf': '2023-03-10T21:52:28.739Z',
#    'clp': '2023-03-10T01:28:26.163Z',
#    'cny': '2023-03-10T21:41:34.404Z',
#    'czk': '2023-03-10T01:28:26.163Z',
#    'dkk': '2023-03-10T01:28:26.163Z',
#    'dot': '2023-02-19T16:19:06.114Z',
#    'eos': '2023-03-03T23:49:30.877Z',
#    'eth': '2023-04-14T21:33:25.751Z',
#    'eur': '2023-03-10T01:28:26.163Z',
#    'gbp': '2023-03-10T21:52:28.739Z',
#    'hkd': '2023-03-09T21:02:30.419Z',
#    'huf': '2023-03-10T01:28:26.163Z',
#    'idr': '2023-03-10T01:28:26.163Z',
#    'ils': '2023-03-09T21:02:30.419Z',
#    'inr': '2023-03-09T21:02:30.419Z',
#    'jpy': '2023-03-10T01:28:26.163Z',
#    'krw': '2023-03-10T01:28:26.163Z',
#    'kwd': '2023-03-09T21:02:30.419Z',
#    'lkr': '2023-03-10T21:41:34.404Z',
#    'ltc': '2023-03-02T08:20:21.478Z',
#    'mmk': '2023-03-09T21:02:30.419Z',
#    'mxn': '2023-03-09T21:02:30.419Z',
#    'myr': '2023-03-09T21:02:30.419Z',
#    'ngn': '2023-03-09T21:02:30.419Z',
#    'nok': '2023-03-09T21:02:30.419Z',
#    'nzd': '2023-03-10T01:28:26.163Z',
#    'php': '2023-03-09T21:02:30.419Z',
#    'pkr': '2023-01-01T05:05:06.583Z',
#    'pln': '2023-03-10T01:28:26.163Z',
#    'rub': '2023-03-10T01:28:26.163Z',
#    'sar': '2023-03-09T21:02:30.419Z',
#    'sek': '2023-03-10T01:28:26.163Z',
#    'sgd': '2023-03-09T21:02:30.419Z',
#    'thb': '2023-03-10T01:28:26.163Z',
#    'try': '2023-03-10T01:20:15.706Z',
#    'twd': '2023-03-09T21:02:30.419Z',
#    'uah': '2023-03-09T21:02:30.419Z',
#    'usd': '2023-03-09T21:02:30.419Z',
#    'vef': '2023-03-09T21:02:30.419Z',
#    'vnd': '2023-03-09T21:02:30.419Z',
#    'xag': '2023-04-07T12:01:24.447Z',
#    'xau': '2023-03-10T21:52:28.739Z',
#    'xdr': '2023-03-09T21:02:30.419Z',
#    'xlm': '2023-04-01T05:10:31.217Z',
#    'xrp': '2023-03-29T19:13:31.879Z',
#    'yfi': '2023-03-03T14:15:11.700Z',
#    'zar': '2023-03-10T21:41:34.404Z',
#    'bits': '2023-04-13T06:02:21.061Z',
#    'link': '2023-02-20T08:13:42.280Z',
#    'sats': '2023-04-13T06:02:21.061Z'},
#   'market_cap': {'aed': 0.0,
#    'ars': 0.0,
#    'aud': 0.0,
#    'bch': 0.0,
#    'bdt': 0.0,
#    'bhd': 0.0,
#    'bmd': 0.0,
#    'bnb': 0.0,
#    'brl': 0.0,
#    'btc': 0.0,
#    'cad': 0.0,
#    'chf': 0.0,
#    'clp': 0.0,
#    'cny': 0.0,
#    'czk': 0.0,
#    'dkk': 0.0,
#    'dot': 0.0,
#    'eos': 0.0,
#    'eth': 0.0,
#    'eur': 0.0,
#    'gbp': 0.0,
#    'hkd': 0.0,
#    'huf': 0.0,
#    'idr': 0.0,
#    'ils': 0.0,
#    'inr': 0.0,
#    'jpy': 0.0,
#    'krw': 0.0,
#    'kwd': 0.0,
#    'lkr': 0.0,
#    'ltc': 0.0,
#    'mmk': 0.0,
#    'mxn': 0.0,
#    'myr': 0.0,
#    'ngn': 0.0,
#    'nok': 0.0,
#    'nzd': 0.0,
#    'php': 0.0,
#    'pkr': 0.0,
#    'pln': 0.0,
#    'rub': 0.0,
#    'sar': 0.0,
#    'sek': 0.0,
#    'sgd': 0.0,
#    'thb': 0.0,
#    'try': 0.0,
#    'twd': 0.0,
#    'uah': 0.0,
#    'usd': 0.0,
#    'vef': 0.0,
#    'vnd': 0.0,
#    'xag': 0.0,
#    'xau': 0.0,
#    'xdr': 0.0,
#    'xlm': 0.0,
#    'xrp': 0.0,
#    'yfi': 0.0,
#    'zar': 0.0,
#    'bits': 0.0,
#    'link': 0.0,
#    'sats': 0.0},
#   'market_cap_rank': None,
#   'fully_diluted_valuation': {'aed': 335588,
#    'ars': 19473841,
#    'aud': 136251,
#    'bch': 685.126,
#    'bdt': 9684376,
#    'bhd': 34308,
#    'bmd': 91384,
#    'bnb': 270.497,
#    'brl': 448684,
#    'btc': 3.018697,
#    'cad': 123537,
#    'chf': 81593,
#    'clp': 72336557,
#    'cny': 627942,
#    'czk': 1938437,
#    'dkk': 619233,
#    'dot': 13597,
#    'eos': 73773,
#    'eth': 43.698646,
#    'eur': 82309,
#    'gbp': 73560,
#    'hkd': 717356,
#    'huf': 31049841,
#    'idr': 1350846130,
#    'ils': 333094,
#    'inr': 7479030,
#    'jpy': 12228488,
#    'krw': 119197944,
#    'kwd': 27832,
#    'lkr': 29396289,
#    'ltc': 939.57,
#    'mmk': 191111921,
#    'mxn': 1645891,
#    'myr': 402270,
#    'ngn': 41904174,
#    'nok': 944821,
#    'nzd': 147084,
#    'php': 5057987,
#    'pkr': 25561477,
#    'pln': 385768,
#    'rub': 7453796,
#    'sar': 342772,
#    'sek': 944102,
#    'sgd': 121577,
#    'thb': 3098292,
#    'try': 1769130,
#    'twd': 2788934,
#    'uah': 3361197,
#    'usd': 91384,
#    'vef': 9150.23,
#    'vnd': 2142030113,
#    'xag': 3598.56,
#    'xau': 45.59,
#    'xdr': 67325,
#    'xlm': 859320,
#    'xrp': 176002,
#    'yfi': 10.036543,
#    'zar': 1646573,
#    'bits': 3018697,
#    'link': 11450,
#    'sats': 301869738},
#   'total_volume': {'aed': 21.14,
#    'ars': 1226.68,
#    'aud': 8.58,
#    'bch': 0.04311963,
#    'bdt': 610.03,
#    'bhd': 2.16,
#    'bmd': 5.76,
#    'bnb': 0.01697919,
#    'brl': 28.26,
#    'btc': 0.00019018,
#    'cad': 7.78,
#    'chf': 5.14,
#    'clp': 4556.57,
#    'cny': 39.55,
#    'czk': 122.1,
#    'dkk': 39.01,
#    'dot': 0.85585941,
#    'eos': 4.642144,
#    'eth': 0.00275205,
#    'eur': 5.18,
#    'gbp': 4.63,
#    'hkd': 45.19,
#    'huf': 1955.87,
#    'idr': 85091,
#    'ils': 20.98,
#    'inr': 471.11,
#    'jpy': 770.29,
#    'krw': 7508.42,
#    'kwd': 1.75,
#    'lkr': 1851.71,
#    'ltc': 0.05920788,
#    'mmk': 12038.37,
#    'mxn': 103.68,
#    'myr': 25.34,
#    'ngn': 2639.59,
#    'nok': 59.52,
#    'nzd': 9.27,
#    'php': 318.61,
#    'pkr': 1610.15,
#    'pln': 24.3,
#    'rub': 469.52,
#    'sar': 21.59,
#    'sek': 59.47,
#    'sgd': 7.66,
#    'thb': 195.17,
#    'try': 111.44,
#    'twd': 175.68,
#    'uah': 211.73,
#    'usd': 5.76,
#    'vef': 0.576384,
#    'vnd': 134929,
#    'xag': 0.226677,
#    'xau': 0.00287185,
#    'xdr': 4.24,
#    'xlm': 54.1,
#    'xrp': 11.078967,
#    'yfi': 0.00063192,
#    'zar': 103.72,
#    'bits': 190.18,
#    'link': 0.72080147,
#    'sats': 19017.78},
#   'high_24h': {'aed': 0.00033559,
#    'ars': 0.01947384,
#    'aud': 0.00013625,
#    'bch': 6.85126e-07,
#    'bdt': 0.00968438,
#    'bhd': 3.431e-05,
#    'bmd': 9.138e-05,
#    'bnb': 2.70964e-07,
#    'brl': 0.00044868,
#    'btc': 3.019e-09,
#    'cad': 0.00012354,
#    'chf': 8.159e-05,
#    'clp': 0.072337,
#    'cny': 0.00062794,
#    'czk': 0.00193844,
#    'dkk': 0.00061923,
#    'dot': 1.36e-05,
#    'eos': 7.377e-05,
#    'eth': 4.3699e-08,
#    'eur': 8.231e-05,
#    'gbp': 7.356e-05,
#    'hkd': 0.00071736,
#    'huf': 0.03104984,
#    'idr': 1.35,
#    'ils': 0.00033309,
#    'inr': 0.00747903,
#    'jpy': 0.01222849,
#    'krw': 0.119198,
#    'kwd': 2.783e-05,
#    'lkr': 0.02939629,
#    'ltc': 9.40365e-07,
#    'mmk': 0.191112,
#    'mxn': 0.00164589,
#    'myr': 0.00040227,
#    'ngn': 0.04190417,
#    'nok': 0.00094482,
#    'nzd': 0.00014708,
#    'php': 0.00505799,
#    'pkr': 0.02556148,
#    'pln': 0.00038577,
#    'rub': 0.0074538,
#    'sar': 0.00034277,
#    'sek': 0.0009441,
#    'sgd': 0.00012158,
#    'thb': 0.00309829,
#    'try': 0.00176913,
#    'twd': 0.00278893,
#    'uah': 0.0033612,
#    'usd': 9.138e-05,
#    'vef': 9.15e-06,
#    'vnd': 2.14,
#    'xag': 3.6e-06,
#    'xau': 4.5591e-08,
#    'xdr': 6.732e-05,
#    'xlm': 0.00085932,
#    'xrp': 0.000176,
#    'yfi': 1.0041e-08,
#    'zar': 0.00164657,
#    'bits': 0.0030187,
#    'link': 1.145e-05,
#    'sats': 0.30187},
#   'low_24h': {'aed': 0.00033111,
#    'ars': 0.01921393,
#    'aud': 0.00013443,
#    'bch': 6.75346e-07,
#    'bdt': 0.00955512,
#    'bhd': 3.385e-05,
#    'bmd': 9.016e-05,
#    'bnb': 2.69116e-07,
#    'brl': 0.0004427,
#    'btc': 2.975e-09,
#    'cad': 0.00012189,
#    'chf': 8.05e-05,
#    'clp': 0.071371,
#    'cny': 0.00061956,
#    'czk': 0.00191256,
#    'dkk': 0.00061097,
#    'dot': 1.339e-05,
#    'eos': 7.271e-05,
#    'eth': 4.3117e-08,
#    'eur': 8.121e-05,
#    'gbp': 7.258e-05,
#    'hkd': 0.00070778,
#    'huf': 0.03063542,
#    'idr': 1.33,
#    'ils': 0.00032865,
#    'inr': 0.00737921,
#    'jpy': 0.01206528,
#    'krw': 0.117607,
#    'kwd': 2.746e-05,
#    'lkr': 0.02900394,
#    'ltc': 9.31243e-07,
#    'mmk': 0.188561,
#    'mxn': 0.00162392,
#    'myr': 0.0003969,
#    'ngn': 0.04134488,
#    'nok': 0.00093221,
#    'nzd': 0.00014512,
#    'php': 0.00499048,
#    'pkr': 0.02522031,
#    'pln': 0.00038062,
#    'rub': 0.00735431,
#    'sar': 0.0003382,
#    'sek': 0.0009315,
#    'sgd': 0.00011995,
#    'thb': 0.00305694,
#    'try': 0.00174552,
#    'twd': 0.00275171,
#    'uah': 0.00331634,
#    'usd': 9.016e-05,
#    'vef': 9.03e-06,
#    'vnd': 2.11,
#    'xag': 3.55e-06,
#    'xau': 4.4983e-08,
#    'xdr': 6.643e-05,
#    'xlm': 0.00084534,
#    'xrp': 0.00017358,
#    'yfi': 9.878e-09,
#    'zar': 0.0016246,
#    'bits': 0.00297473,
#    'link': 1.128e-05,
#    'sats': 0.297473},
#   'price_change_24h': 1.26e-06,
#   'price_change_percentage_24h': 1.39299,
#   'price_change_percentage_7d': 8.80981,
#   'price_change_percentage_14d': 6.03213,
#   'price_change_percentage_30d': 0.49638,
#   'price_change_percentage_60d': 6.49466,
#   'price_change_percentage_200d': 0.0,
#   'price_change_percentage_1y': 0.0,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'price_change_24h_in_currency': {'aed': 4.61e-06,
#    'ars': 0.00026765,
#    'aud': 1.87e-06,
#    'bch': 9.079e-09,
#    'bdt': 0.0001331,
#    'bhd': 4.71535e-07,
#    'bmd': 1.26e-06,
#    'bnb': -2.34019304e-10,
#    'brl': 6.17e-06,
#    'btc': 4.5583e-11,
#    'cad': 1.7e-06,
#    'chf': 1.12e-06,
#    'clp': 0.00099419,
#    'cny': 8.63e-06,
#    'czk': 2.664e-05,
#    'dkk': 8.51e-06,
#    'dot': 2.06225e-07,
#    'eos': 1.01e-06,
#    'eth': 5.89295e-10,
#    'eur': 1.13e-06,
#    'gbp': 1.01e-06,
#    'hkd': 9.86e-06,
#    'huf': 0.00042675,
#    'idr': 0.01856604,
#    'ils': 4.58e-06,
#    'inr': 0.00010279,
#    'jpy': 0.00016807,
#    'krw': 0.00163826,
#    'kwd': 3.82521e-07,
#    'lkr': 0.00040402,
#    'ltc': 5.228e-09,
#    'mmk': 0.00262664,
#    'mxn': 2.262e-05,
#    'myr': 5.53e-06,
#    'ngn': 0.00057593,
#    'nok': 1.299e-05,
#    'nzd': 2.02e-06,
#    'php': 6.952e-05,
#    'pkr': 0.00035132,
#    'pln': 5.3e-06,
#    'rub': 0.00010245,
#    'sar': 4.71e-06,
#    'sek': 1.298e-05,
#    'sgd': 1.67e-06,
#    'thb': 4.258e-05,
#    'try': 2.431e-05,
#    'twd': 3.833e-05,
#    'uah': 4.62e-05,
#    'usd': 1.26e-06,
#    'vef': 1.25761e-07,
#    'vnd': 0.02944007,
#    'xag': 4.9459e-08,
#    'xau': 6.26606e-10,
#    'xdr': 9.25313e-07,
#    'xlm': 1.385e-05,
#    'xrp': 2.31e-06,
#    'yfi': 1.57791e-10,
#    'zar': 2.263e-05,
#    'bits': 4.558e-05,
#    'link': 1.65997e-07,
#    'sats': 0.00455825},
#   'price_change_percentage_1h_in_currency': {'aed': 1.32872,
#    'ars': 1.32872,
#    'aud': 1.32872,
#    'bch': 1.09736,
#    'bdt': 1.32872,
#    'bhd': 1.32872,
#    'bmd': 1.32872,
#    'bnb': -0.08669,
#    'brl': 1.32872,
#    'btc': 1.35771,
#    'cad': 1.32872,
#    'chf': 1.32872,
#    'clp': 1.32872,
#    'cny': 1.32872,
#    'czk': 1.32872,
#    'dkk': 1.32872,
#    'dot': 0.85253,
#    'eos': 1.0632,
#    'eth': 1.13287,
#    'eur': 1.32872,
#    'gbp': 1.32872,
#    'hkd': 1.32872,
#    'huf': 1.32872,
#    'idr': 1.32872,
#    'ils': 1.32872,
#    'inr': 1.32872,
#    'jpy': 1.32872,
#    'krw': 1.32872,
#    'kwd': 1.32872,
#    'lkr': 1.32872,
#    'ltc': 0.67179,
#    'mmk': 1.32872,
#    'mxn': 1.32872,
#    'myr': 1.32872,
#    'ngn': 1.32872,
#    'nok': 1.32872,
#    'nzd': 1.32872,
#    'php': 1.32872,
#    'pkr': 1.32872,
#    'pln': 1.32872,
#    'rub': 1.32872,
#    'sar': 1.32872,
#    'sek': 1.32872,
#    'sgd': 1.32872,
#    'thb': 1.32872,
#    'try': 1.32872,
#    'twd': 1.32872,
#    'uah': 1.32872,
#    'usd': 1.32872,
#    'vef': 1.32872,
#    'vnd': 1.32872,
#    'xag': 1.32872,
#    'xau': 1.32872,
#    'xdr': 1.32872,
#    'xlm': 1.21372,
#    'xrp': 1.18482,
#    'yfi': 1.0467,
#    'zar': 1.32872,
#    'bits': 1.35771,
#    'link': 1.07418,
#    'sats': 1.35771},
#   'price_change_percentage_24h_in_currency': {'aed': 1.39299,
#    'ars': 1.39299,
#    'aud': 1.39299,
#    'bch': 1.34352,
#    'bdt': 1.39299,
#    'bhd': 1.39299,
#    'bmd': 1.39299,
#    'bnb': -0.08671,
#    'brl': 1.39299,
#    'btc': 1.53232,
#    'cad': 1.39299,
#    'chf': 1.39299,
#    'clp': 1.39299,
#    'cny': 1.39299,
#    'czk': 1.39299,
#    'dkk': 1.39299,
#    'dot': 1.54058,
#    'eos': 1.38921,
#    'eth': 1.36672,
#    'eur': 1.39299,
#    'gbp': 1.39299,
#    'hkd': 1.39299,
#    'huf': 1.39299,
#    'idr': 1.39299,
#    'ils': 1.39299,
#    'inr': 1.39299,
#    'jpy': 1.39299,
#    'krw': 1.39299,
#    'kwd': 1.39299,
#    'lkr': 1.39299,
#    'ltc': 0.55904,
#    'mmk': 1.39299,
#    'mxn': 1.39299,
#    'myr': 1.39299,
#    'ngn': 1.39299,
#    'nok': 1.39299,
#    'nzd': 1.39299,
#    'php': 1.39299,
#    'pkr': 1.39299,
#    'pln': 1.39299,
#    'rub': 1.39299,
#    'sar': 1.39299,
#    'sek': 1.39299,
#    'sgd': 1.39299,
#    'thb': 1.39299,
#    'try': 1.39299,
#    'twd': 1.39299,
#    'uah': 1.39299,
#    'usd': 1.39299,
#    'vef': 1.39299,
#    'vnd': 1.39299,
#    'xag': 1.39299,
#    'xau': 1.39299,
#    'xdr': 1.39299,
#    'xlm': 1.63855,
#    'xrp': 1.33055,
#    'yfi': 1.59739,
#    'zar': 1.39299,
#    'bits': 1.53232,
#    'link': 1.47142,
#    'sats': 1.53232},
#   'price_change_percentage_7d_in_currency': {'aed': 8.80107,
#    'ars': 10.53527,
#    'aud': 8.24203,
#    'bch': 1.03625,
#    'bdt': 9.69082,
#    'bhd': 8.37163,
#    'bmd': 8.80981,
#    'bnb': -0.20056,
#    'brl': 5.64931,
#    'btc': 0.56953,
#    'cad': 8.4808,
#    'chf': 7.28346,
#    'clp': 5.25821,
#    'cny': 8.82248,
#    'czk': 7.94976,
#    'dkk': 7.94323,
#    'dot': -0.71835,
#    'eos': 4.6738,
#    'eth': -3.67106,
#    'eur': 7.75132,
#    'gbp': 8.79238,
#    'hkd': 8.81259,
#    'huf': 7.35794,
#    'idr': 7.65341,
#    'ils': 10.13808,
#    'inr': 8.81208,
#    'jpy': 10.17661,
#    'krw': 7.81217,
#    'kwd': 8.01925,
#    'lkr': 10.22907,
#    'ltc': 0.72864,
#    'mmk': 8.34286,
#    'mxn': 8.11946,
#    'myr': 8.7851,
#    'ngn': 7.30116,
#    'nok': 7.19218,
#    'nzd': 9.77303,
#    'php': 10.52511,
#    'pkr': 7.16864,
#    'pln': 7.10081,
#    'rub': 9.29793,
#    'sar': 8.80407,
#    'sek': 7.34375,
#    'sgd': 8.85891,
#    'thb': 8.95658,
#    'try': 9.43672,
#    'twd': 9.20664,
#    'uah': 8.84445,
#    'usd': 8.80981,
#    'vef': 8.80981,
#    'vnd': 8.77891,
#    'xag': 7.01661,
#    'xau': 8.98676,
#    'xdr': 8.02695,
#    'xlm': 6.77301,
#    'xrp': 6.05704,
#    'yfi': 3.74973,
#    'zar': 7.49119,
#    'bits': 0.56953,
#    'link': -2.66704,
#    'sats': 0.56953},
#   'price_change_percentage_14d_in_currency': {'aed': 6.02058,
#    'ars': 8.42895,
#    'aud': 5.73181,
#    'bch': 0.34775,
#    'bdt': 4.99918,
#    'bhd': 5.71451,
#    'bmd': 6.03213,
#    'bnb': -1.41271,
#    'brl': 2.81973,
#    'btc': -0.1498,
#    'cad': 5.95375,
#    'chf': 3.48188,
#    'clp': 6.12075,
#    'cny': 6.07381,
#    'czk': 3.90909,
#    'dkk': 4.56767,
#    'dot': 0.2213,
#    'eos': 2.21428,
#    'eth': -7.54501,
#    'eur': 3.78779,
#    'gbp': 5.36639,
#    'hkd': 6.03213,
#    'huf': 2.87564,
#    'idr': 4.71111,
#    'ils': 7.34438,
#    'inr': 5.59545,
#    'jpy': 6.86261,
#    'krw': 5.8617,
#    'kwd': 5.30466,
#    'lkr': 3.3409,
#    'ltc': 1.10974,
#    'mmk': 5.67116,
#    'mxn': 5.99564,
#    'myr': 5.77982,
#    'ngn': 5.62047,
#    'nok': 4.50857,
#    'nzd': 6.80012,
#    'php': 8.09545,
#    'pkr': 4.50645,
#    'pln': 3.70506,
#    'rub': 11.55772,
#    'sar': 5.9926,
#    'sek': 5.54889,
#    'sgd': 6.00026,
#    'thb': 5.47253,
#    'try': 7.03395,
#    'twd': 5.95887,
#    'uah': 6.34883,
#    'usd': 6.03213,
#    'vef': 6.03213,
#    'vnd': 5.82896,
#    'xag': 0.64588,
#    'xau': 4.18401,
#    'xdr': 5.02441,
#    'xlm': 7.96311,
#    'xrp': 4.33276,
#    'yfi': 2.34527,
#    'zar': 7.36937,
#    'bits': -0.1498,
#    'link': 0.34252,
#    'sats': -0.1498},
#   'price_change_percentage_30d_in_currency': {'aed': 0.4827,
#    'ars': 5.5262,
#    'aud': -0.13956,
#    'bch': -4.34077,
#    'bdt': -0.7337,
#    'bhd': 0.06327,
#    'bmd': 0.49638,
#    'bnb': -1.72503,
#    'brl': -5.68872,
#    'btc': -16.49911,
#    'cad': -0.95813,
#    'chf': -3.42,
#    'clp': -3.74448,
#    'cny': 0.10305,
#    'czk': -5.67943,
#    'dkk': -2.90389,
#    'dot': -8.41888,
#    'eos': -11.84242,
#    'eth': -19.31359,
#    'eur': -3.91182,
#    'gbp': -2.01319,
#    'hkd': 0.5015,
#    'huf': -8.15288,
#    'idr': -3.71406,
#    'ils': -0.03569,
#    'inr': -0.45314,
#    'jpy': 0.83384,
#    'krw': 0.68356,
#    'kwd': -0.33254,
#    'lkr': -5.51505,
#    'ltc': -17.84819,
#    'mmk': 0.04359,
#    'mxn': -3.55766,
#    'myr': -1.77952,
#    'ngn': 0.09346,
#    'nok': -3.34775,
#    'nzd': 0.35491,
#    'php': 1.86564,
#    'pkr': -0.42692,
#    'pln': -4.14938,
#    'rub': 7.13603,
#    'sar': 0.33059,
#    'sek': -1.14644,
#    'sgd': -0.67198,
#    'thb': -1.03815,
#    'try': 2.35533,
#    'twd': 0.34841,
#    'uah': 0.53894,
#    'usd': 0.49638,
#    'vef': 0.49638,
#    'vnd': -0.08577,
#    'xag': -13.9046,
#    'xau': -3.65186,
#    'xdr': -1.77979,
#    'xlm': -19.58752,
#    'xrp': -28.73501,
#    'yfi': -8.18561,
#    'zar': -1.49877,
#    'bits': -16.49911,
#    'link': -15.62168,
#    'sats': -16.49911},
#   'price_change_percentage_60d_in_currency': {'aed': 6.47413,
#    'ars': 18.19009,
#    'aud': 10.94533,
#    'bch': 1.12404,
#    'bdt': 5.35044,
#    'bhd': 6.05595,
#    'bmd': 6.49466,
#    'bnb': -6.91488,
#    'brl': 0.6929,
#    'btc': -21.78016,
#    'cad': 7.94027,
#    'chf': 3.16524,
#    'clp': 7.06829,
#    'cny': 7.19038,
#    'czk': 2.32303,
#    'dkk': 3.95882,
#    'dot': -1.32041,
#    'eos': -9.96445,
#    'eth': -20.63284,
#    'eur': 2.96611,
#    'gbp': 4.3491,
#    'hkd': 6.50415,
#    'huf': 2.84561,
#    'idr': 3.66027,
#    'ils': 10.18639,
#    'inr': 5.1781,
#    'jpy': 7.07699,
#    'krw': 9.15032,
#    'kwd': 5.97307,
#    'lkr': -6.1267,
#    'ltc': 4.66459,
#    'mmk': 6.07566,
#    'mxn': 3.6265,
#    'myr': 7.80487,
#    'ngn': 5.98863,
#    'nok': 8.6166,
#    'nzd': 8.59686,
#    'php': 7.25815,
#    'pkr': 11.43338,
#    'pln': 1.05285,
#    'rub': 18.02547,
#    'sar': 6.45424,
#    'sek': 6.16684,
#    'sgd': 6.64696,
#    'thb': 6.5497,
#    'try': 9.38242,
#    'twd': 7.33911,
#    'uah': 6.61258,
#    'usd': 6.49466,
#    'vef': 6.49466,
#    'vnd': 5.72801,
#    'xag': -8.31716,
#    'xau': -1.46662,
#    'xdr': 4.92139,
#    'xlm': -14.0431,
#    'xrp': -21.3646,
#    'yfi': -17.16185,
#    'zar': 7.25273,
#    'bits': -21.78016,
#    'link': -9.10301,
#    'sats': -21.78016},
#   'price_change_percentage_200d_in_currency': {},
#   'price_change_percentage_1y_in_currency': {},
#   'market_cap_change_24h_in_currency': {'aed': 0.0,
#    'ars': 0.0,
#    'aud': 0.0,
#    'bch': 0.0,
#    'bdt': 0.0,
#    'bhd': 0.0,
#    'bmd': 0.0,
#    'bnb': 0.0,
#    'brl': 0.0,
#    'btc': 0.0,
#    'cad': 0.0,
#    'chf': 0.0,
#    'clp': 0.0,
#    'cny': 0.0,
#    'czk': 0.0,
#    'dkk': 0.0,
#    'dot': 0.0,
#    'eos': 0.0,
#    'eth': 0.0,
#    'eur': 0.0,
#    'gbp': 0.0,
#    'hkd': 0.0,
#    'huf': 0.0,
#    'idr': 0.0,
#    'ils': 0.0,
#    'inr': 0.0,
#    'jpy': 0.0,
#    'krw': 0.0,
#    'kwd': 0.0,
#    'lkr': 0.0,
#    'ltc': 0.0,
#    'mmk': 0.0,
#    'mxn': 0.0,
#    'myr': 0.0,
#    'ngn': 0.0,
#    'nok': 0.0,
#    'nzd': 0.0,
#    'php': 0.0,
#    'pkr': 0.0,
#    'pln': 0.0,
#    'rub': 0.0,
#    'sar': 0.0,
#    'sek': 0.0,
#    'sgd': 0.0,
#    'thb': 0.0,
#    'try': 0.0,
#    'twd': 0.0,
#    'uah': 0.0,
#    'usd': 0.0,
#    'vef': 0.0,
#    'vnd': 0.0,
#    'xag': 0.0,
#    'xau': 0.0,
#    'xdr': 0.0,
#    'xlm': 0.0,
#    'xrp': 0.0,
#    'yfi': 0.0,
#    'zar': 0.0,
#    'bits': 0.0,
#    'link': 0.0,
#    'sats': 0.0},
#   'market_cap_change_percentage_24h_in_currency': {'aed': 0.0,
#    'ars': 0.0,
#    'aud': 0.0,
#    'bch': 0.0,
#    'bdt': 0.0,
#    'bhd': 0.0,
#    'bmd': 0.0,
#    'bnb': 0.0,
#    'brl': 0.0,
#    'btc': 0.0,
#    'cad': 0.0,
#    'chf': 0.0,
#    'clp': 0.0,
#    'cny': 0.0,
#    'czk': 0.0,
#    'dkk': 0.0,
#    'dot': 0.0,
#    'eos': 0.0,
#    'eth': 0.0,
#    'eur': 0.0,
#    'gbp': 0.0,
#    'hkd': 0.0,
#    'huf': 0.0,
#    'idr': 0.0,
#    'ils': 0.0,
#    'inr': 0.0,
#    'jpy': 0.0,
#    'krw': 0.0,
#    'kwd': 0.0,
#    'lkr': 0.0,
#    'ltc': 0.0,
#    'mmk': 0.0,
#    'mxn': 0.0,
#    'myr': 0.0,
#    'ngn': 0.0,
#    'nok': 0.0,
#    'nzd': 0.0,
#    'php': 0.0,
#    'pkr': 0.0,
#    'pln': 0.0,
#    'rub': 0.0,
#    'sar': 0.0,
#    'sek': 0.0,
#    'sgd': 0.0,
#    'thb': 0.0,
#    'try': 0.0,
#    'twd': 0.0,
#    'uah': 0.0,
#    'usd': 0.0,
#    'vef': 0.0,
#    'vnd': 0.0,
#    'xag': 0.0,
#    'xau': 0.0,
#    'xdr': 0.0,
#    'xlm': 0.0,
#    'xrp': 0.0,
#    'yfi': 0.0,
#    'zar': 0.0,
#    'bits': 0.0,
#    'link': 0.0,
#    'sats': 0.0},
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'circulating_supply': 0.0,
#   'last_updated': '2023-04-16T12:47:39.587Z'},
#  'community_data': {'facebook_likes': None,
#   'twitter_followers': 0,
#   'reddit_average_posts_48h': 0.0,
#   'reddit_average_comments_48h': 0.0,
#   'reddit_subscribers': 0,
#   'reddit_accounts_active_48h': 0,
#   'telegram_channel_user_count': 11023},
#  'developer_data': {'forks': 0,
#   'stars': 0,
#   'subscribers': 0,
#   'total_issues': 0,
#   'closed_issues': 0,
#   'pull_requests_merged': 0,
#   'pull_request_contributors': 0,
#   'code_additions_deletions_4_weeks': {'additions': None, 'deletions': None},
#   'commit_count_4_weeks': 0,
#   'last_4_weeks_commit_activity_series': []},
#  'public_interest_stats': {'alexa_rank': None, 'bing_matches': None},
#  'status_updates': [],
#  'last_updated': '2023-04-16T12:47:39.587Z',
#  'tickers': [{'base': '0X27DCC73CBBBE57D006303316DD3E91A0D5D58EEA',
#    'target': 'WBNB',
#    'market': {'name': 'PancakeSwap (v2)',
#     'identifier': 'pancakeswap_new',
#     'has_trading_incentive': False},
#    'last': 2.69719208788831e-07,
#    'volume': 62965.1676073314,
#    'converted_last': {'btc': 3.02e-09, 'eth': 4.3707e-08, 'usd': 9.142e-05},
#    'converted_volume': {'btc': 0.00019018, 'eth': 0.00275205, 'usd': 5.76},
#    'trust_score': 'yellow',
#    'bid_ask_spread_percentage': 0.605959,
#    'timestamp': '2023-04-16T10:50:56+00:00',
#    'last_traded_at': '2023-04-16T10:50:56+00:00',
#    'last_fetch_at': '2023-04-16T12:47:39+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pancakeswap.finance/swap?inputCurrency=0x27dcc73cbbbe57d006303316dd3e91a0d5d58eea&outputCurrency=0xbb4cdb9cbd36b01bd1cbaebf2de08d9173bc095c',
#    'token_info_url': None,
#    'coin_id': 'shiba-world-cup',
#    'target_coin_id': 'wbnb'}]}

# %%
cg.get_search_trending()

# unfortuanetly no historical data for this
# Out:
# {'coins': [{'item': {'id': 'arbitrum',
#     'coin_id': 16547,
#     'name': 'Arbitrum',
#     'symbol': 'ARB',
#     'market_cap_rank': 34,
#     'thumb': 'https://assets.coingecko.com/coins/images/16547/thumb/photo_2023-03-29_21.47.00.jpeg?1680097630',
#     'small': 'https://assets.coingecko.com/coins/images/16547/small/photo_2023-03-29_21.47.00.jpeg?1680097630',
#     'large': 'https://assets.coingecko.com/coins/images/16547/large/photo_2023-03-29_21.47.00.jpeg?1680097630',
#     'slug': 'arbitrum',
#     'price_btc': 5.325666542074022e-05,
#     'score': 0}},
#   {'item': {'id': 'chromaway',
#     'coin_id': 5000,
#     'name': 'Chromia',
#     'symbol': 'CHR',
#     'market_cap_rank': 299,
#     'thumb': 'https://assets.coingecko.com/coins/images/5000/thumb/Chromia.png?1559038018',
#     'small': 'https://assets.coingecko.com/coins/images/5000/small/Chromia.png?1559038018',
#     'large': 'https://assets.coingecko.com/coins/images/5000/large/Chromia.png?1559038018',
#     'slug': 'chromia',
#     'price_btc': 6.143152115423967e-06,
#     'score': 1}},
#   {'item': {'id': 'baby-doge-coin',
#     'coin_id': 16125,
#     'name': 'Baby Doge Coin',
#     'symbol': 'BABYDOGE',
#     'market_cap_rank': 93,
#     'thumb': 'https://assets.coingecko.com/coins/images/16125/thumb/babydoge.jpg?1676303229',
#     'small': 'https://assets.coingecko.com/coins/images/16125/small/babydoge.jpg?1676303229',
#     'large': 'https://assets.coingecko.com/coins/images/16125/large/babydoge.jpg?1676303229',
#     'slug': 'baby-doge-coin',
#     'price_btc': 1.1733316574112777e-13,
#     'score': 2}},
#   {'item': {'id': 'tominet',
#     'coin_id': 28730,
#     'name': 'tomiNet',
#     'symbol': 'TOMI',
#     'market_cap_rank': 258,
#     'thumb': 'https://assets.coingecko.com/coins/images/28730/thumb/logo_for_token.png?1673690005',
#     'small': 'https://assets.coingecko.com/coins/images/28730/small/logo_for_token.png?1673690005',
#     'large': 'https://assets.coingecko.com/coins/images/28730/large/logo_for_token.png?1673690005',
#     'slug': 'tominet',
#     'price_btc': 8.28019302900119e-05,
#     'score': 3}},
#   {'item': {'id': 'space-id',
#     'coin_id': 29468,
#     'name': 'SPACE ID',
#     'symbol': 'ID',
#     'market_cap_rank': 171,
#     'thumb': 'https://assets.coingecko.com/coins/images/29468/thumb/sid_token_logo_%28green2%29.png?1679454702',
#     'small': 'https://assets.coingecko.com/coins/images/29468/small/sid_token_logo_%28green2%29.png?1679454702',
#     'large': 'https://assets.coingecko.com/coins/images/29468/large/sid_token_logo_%28green2%29.png?1679454702',
#     'slug': 'space-id',
#     'price_btc': 2.9124396052870205e-05,
#     'score': 4}},
#   {'item': {'id': 'xen-crypto',
#     'coin_id': 27713,
#     'name': 'XEN Crypto',
#     'symbol': 'XEN',
#     'market_cap_rank': 486,
#     'thumb': 'https://assets.coingecko.com/coins/images/27713/thumb/Xen.jpeg?1665453190',
#     'small': 'https://assets.coingecko.com/coins/images/27713/small/Xen.jpeg?1665453190',
#     'large': 'https://assets.coingecko.com/coins/images/27713/large/Xen.jpeg?1665453190',
#     'slug': 'xen-crypto',
#     'price_btc': 1.7496401273742097e-10,
#     'score': 5}},
#   {'item': {'id': 'optimus-ai',
#     'coin_id': 29328,
#     'name': 'Optimus AI',
#     'symbol': 'OPTI',
#     'market_cap_rank': 526,
#     'thumb': 'https://assets.coingecko.com/coins/images/29328/thumb/Optimus_AI_Logo.png?1678170818',
#     'small': 'https://assets.coingecko.com/coins/images/29328/small/Optimus_AI_Logo.png?1678170818',
#     'large': 'https://assets.coingecko.com/coins/images/29328/large/Optimus_AI_Logo.png?1678170818',
#     'slug': 'optimus-ai',
#     'price_btc': 1.6055961137022917e-05,
#     'score': 6}}],
#  'exchanges': []}

# %% [markdown]
# ### Query API for historical prices

# %% [markdown]
# #### Test single execution

# %%
btc_prices = cg.get_coin_market_chart_range_by_id(id='bitcoin', 
                                                  vs_currency='usd', 
                                                  from_timestamp='1661990400', 
                                                  to_timestamp='1664582399')  # from September 1, 2022 to September 30, 2022

# %%
btc_prices.keys()
# Out:
# dict_keys(['prices', 'market_caps', 'total_volumes'])

# %%
len(btc_prices['prices'])
# Out:
# 722

# %%
f'A single day has {int(722/30)} price entries on average'
# Out:
# 'A single day has 24 price entries on average'

# %%
btc_coin_ohlc = cg.get_coin_ohlc_by_id(id='bitcoin',
                                       vs_currency='usd',
                                       days=1)

# %%
coin_ohlc_df = pd.DataFrame(
    btc_coin_ohlc, columns = ['Time', 'Open', 'High', 'Low', 'Close'])
coin_ohlc_df.head()
# Out:
#             Time      Open      High       Low     Close
# 0  1682168400000  27335.45  27364.24  27335.45  27364.24
# 1  1682170200000  27370.72  27378.83  27346.68  27346.68
# 2  1682172000000  27317.43  27337.31  27277.85  27277.85
# 3  1682173800000  27276.35  27298.31  27268.28  27298.31
# 4  1682175600000  27363.04  27423.62  27323.74  27423.62

# %%
f'A single day holds {len(coin_ohlc_df)} entries'
# Out:
# 'A single day holds 48 entries'

# %% [markdown]
# #### Date ranges

# %%
from_date = '2020-03-01'  # let's discard stuff pre-COVID
to_date = '2023-04-15'

# %%
from_date_timestamp = time.mktime(datetime.datetime.strptime(from_date, "%Y-%m-%d").timetuple())
from_date_timestamp
# Out:
# 1583017200.0

# %%
to_date_timestamp = time.mktime(datetime.datetime.strptime(to_date, "%Y-%m-%d").timetuple())
to_date_timestamp
# Out:
# 1681509600.0

# %%
# Initialize an empty dictionary to store the historical data for each coin
# coin_data = {}

# %%
# coin_features = {}

# %%
# for coin in tqdm(all_coins_list):
#     coin_id = coin['id']
#     coin_history = cg.get_coin_market_chart_range_by_id(id=coin_id, 
#                                                         vs_currency='usd', 
#                                                         from_timestamp=from_date_timestamp, 
#                                                         to_timestamp=to_date_timestamp)
    
#     coin_data[coin_id] = coin_history
#     coin_details = cg.get_coin_by_id(coin_id)
    
#     coin_features[coin_id] = coin_details

# %%
# coin_features['1inch']

# %%
# Takes lof of time to compute, let's switch to something smarter!

# %% [markdown]
# ### Async query for prices

# %%
btc_defi_df = dft.geckoHistorical('bitcoin')

# %%
btc_defi_df
# Out:
#                             price   market_caps  total_volumes
# date
# 2013-04-28 00:00:00    135.300000  1.500518e+09   0.000000e+00
# 2013-04-29 00:00:00    141.960000  1.575032e+09   0.000000e+00
# 2013-04-30 00:00:00    135.300000  1.501657e+09   0.000000e+00
# 2013-05-01 00:00:00    117.000000  1.298952e+09   0.000000e+00
# 2013-05-02 00:00:00    103.430000  1.148668e+09   0.000000e+00
# ...                           ...           ...            ...
# 2023-04-20 00:00:00  28833.217501  5.587965e+11   2.413662e+10
# 2023-04-21 00:00:00  28255.578249  5.461411e+11   2.169590e+10
# 2023-04-22 00:00:00  27300.157129  5.283573e+11   2.042033e+10
# 2023-04-23 00:00:00  27861.640663  5.394547e+11   1.170023e+10
# 2023-04-23 06:29:37  27645.655927  5.349183e+11   1.165117e+10
#
# [3647 rows x 3 columns]

# %% [markdown]
# ### Store the results
